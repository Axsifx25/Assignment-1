# %%
pip install faker
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import random
import faker

# %%
# faker is a class faker() generates fake value.
fake= faker.Faker()
# sample data: indian first and last names (including muslim and non muslim.
data = {
    "First Name":["Aarav","Isha","Mohammed","Zoya","Ayaan","Priya","Reyansh"],
    "Last Name":["Sharma","Patel","Khan","Shaikh","Ansari","Verma","Reddy"],
    "Email ID":[fake.email() for _ in range(7)], #Random email using faker
    "Age": [random.randint(18,35) for _ in range(7)] #Random age between 18 to 35
}
print(data)
# Out:
# {'First Name': ['Aarav', 'Isha', 'Mohammed', 'Zoya', 'Ayaan', 'Priya', 'Reyansh'], 'Last Name': ['Sharma', 'Patel', 'Khan', 'Shaikh', 'Ansari', 'Verma', 'Reddy'], 'Email ID': ['jessica84@example.com', 'johnestrada@example.org', 'patriciaperez@example.org', 'david04@example.com', 'pmayer@example.org', 'kdavis@example.net', 'leblanckaren@example.net'], 'Age': [20, 20, 21, 19, 22, 32, 26]}

# %%
ds=pd.DataFrame(data)
ds
# Out:
#   First Name Last Name                   Email ID  Age
# 0      Aarav    Sharma      jessica84@example.com   20
# 1       Isha     Patel    johnestrada@example.org   20
# 2   Mohammed      Khan  patriciaperez@example.org   21
# 3       Zoya    Shaikh        david04@example.com   19
# 4      Ayaan    Ansari         pmayer@example.org   22
# 5      Priya     Verma         kdavis@example.net   32
# 6    Reyansh     Reddy   leblanckaren@example.net   26

# %%
fake = faker.Faker()
print(fake.name())
print(fake.address())
# Out:
# Jessica Carter
# 45827 Patterson Mountain
# East Christina, IN 49698

# %%
fake=faker.Faker()
data=[]
for  _ in range(10):
        record={
            "Name": fake.name(),
            "Address": fake.address(),
            "Email":fake.email(),
            "Date of Birth":fake.date_of_birth(),
            "Phone Number":fake.phone_number(),
            "Company":fake.company()
        }
        data.append(record)
        ds=pd.DataFrame(data)

# %%
ds
# Out:
#                  Name                                            Address  \
# 0         David Smith                   PSC 4943, Box 1244\nAPO AA 95723
# 1         Casey Allen  21393 Patricia Point Suite 062\nGarciaville, L...
# 2       Kelsey Vargas          198 Cassandra View\nJessicaview, KY 28186
# 3       Thomas Nguyen  186 Hernandez Roads Apt. 015\nSabrinaside, LA ...
# 4  Heather Williamson  89142 Travis Harbors Apt. 624\nLake Richard, M...
# 5     Michael Kaufman  23964 Veronica Villages Apt. 964\nLarryburgh, ...
# 6         Brian Rivas    64576 Paul Points Apt. 172\nLake Lisa, DE 61303
# 7     Thomas Robinson       69102 Christine Corners\nLindatown, WA 35074
# 8        Vanessa Yang       86294 Alyssa Lights\nMadelinehaven, WY 47732
# 9     Stephen Simmons             2054 Jason Club\nSampsonland, SC 05019
#
#                           Email Date of Birth           Phone Number  \
# 0       stephanie11@example.com    1928-12-09          (479)658-9478
# ...

# %%
fake= faker.Faker('en_IN')
fake.name()
# Out:
# 'Zinal Vig'

# %%
ds.columns
# Out:
# Index(['Name', 'Address', 'Email', 'Date of Birth', 'Phone Number', 'Company'], dtype='object')

# %%
ds.rename(columns={ds.columns[0]:"Full Name"},inplace=True)

# %%
ds
# Out:
#             Full Name                                            Address  \
# 0         David Smith                   PSC 4943, Box 1244\nAPO AA 95723
# 1         Casey Allen  21393 Patricia Point Suite 062\nGarciaville, L...
# 2       Kelsey Vargas          198 Cassandra View\nJessicaview, KY 28186
# 3       Thomas Nguyen  186 Hernandez Roads Apt. 015\nSabrinaside, LA ...
# 4  Heather Williamson  89142 Travis Harbors Apt. 624\nLake Richard, M...
# 5     Michael Kaufman  23964 Veronica Villages Apt. 964\nLarryburgh, ...
# 6         Brian Rivas    64576 Paul Points Apt. 172\nLake Lisa, DE 61303
# 7     Thomas Robinson       69102 Christine Corners\nLindatown, WA 35074
# 8        Vanessa Yang       86294 Alyssa Lights\nMadelinehaven, WY 47732
# 9     Stephen Simmons             2054 Jason Club\nSampsonland, SC 05019
#
#                           Email Date of Birth           Phone Number  \
# 0       stephanie11@example.com    1928-12-09          (479)658-9478
# ...

# %%
ds.rename(columns=
        {  "Phone Number": "Contact Number",   #
          "Email":"Email Address"             #
          } ,inplace=True)

# %%
ds
# Out:
#             Full Name                                            Address  \
# 0         David Smith                   PSC 4943, Box 1244\nAPO AA 95723
# 1         Casey Allen  21393 Patricia Point Suite 062\nGarciaville, L...
# 2       Kelsey Vargas          198 Cassandra View\nJessicaview, KY 28186
# 3       Thomas Nguyen  186 Hernandez Roads Apt. 015\nSabrinaside, LA ...
# 4  Heather Williamson  89142 Travis Harbors Apt. 624\nLake Richard, M...
# 5     Michael Kaufman  23964 Veronica Villages Apt. 964\nLarryburgh, ...
# 6         Brian Rivas    64576 Paul Points Apt. 172\nLake Lisa, DE 61303
# 7     Thomas Robinson       69102 Christine Corners\nLindatown, WA 35074
# 8        Vanessa Yang       86294 Alyssa Lights\nMadelinehaven, WY 47732
# 9     Stephen Simmons             2054 Jason Club\nSampsonland, SC 05019
#
#                   Email Address Date of Birth         Contact Number  \
# 0       stephanie11@example.com    1928-12-09          (479)658-9478
# ...

# %%
[x.upper() for x in ds.columns]
# Out:
# ['FULL NAME',
#  'ADDRESS',
#  'EMAIL ADDRESS',
#  'DATE OF BIRTH',
#  'CONTACT NUMBER',
#  'COMPANY']

# %%
[x.lower() for x in ds.columns]
# Out:
# ['full name',
#  'address',
#  'email address',
#  'date of birth',
#  'contact number',
#  'company']

# %%
ds.columns.str.replace(' ','_')
# Out:
# Index(['Full_Name', 'Address', 'Email_Address', 'Date_of_Birth',
#        'Contact_Number', 'Company'],
#       dtype='object')

# %%
ds.loc[2]=['Umar','Mumbai','umar@gmail.com','2ndSep1999','6453990434','BFC']

# %%
ds
# Out:
#             Full Name                                            Address  \
# 0         David Smith                   PSC 4943, Box 1244\nAPO AA 95723
# 1         Casey Allen  21393 Patricia Point Suite 062\nGarciaville, L...
# 2                Umar                                             Mumbai
# 3       Thomas Nguyen  186 Hernandez Roads Apt. 015\nSabrinaside, LA ...
# 4  Heather Williamson  89142 Travis Harbors Apt. 624\nLake Richard, M...
# 5     Michael Kaufman  23964 Veronica Villages Apt. 964\nLarryburgh, ...
# 6         Brian Rivas    64576 Paul Points Apt. 172\nLake Lisa, DE 61303
# 7     Thomas Robinson       69102 Christine Corners\nLindatown, WA 35074
# 8        Vanessa Yang       86294 Alyssa Lights\nMadelinehaven, WY 47732
# 9     Stephen Simmons             2054 Jason Club\nSampsonland, SC 05019
#
#                   Email Address Date of Birth         Contact Number  \
# 0       stephanie11@example.com    1928-12-09          (479)658-9478
# ...

# %%
ds.loc[2,['Address']]=['New Delhi']

# %%
ds
# Out:
#             Full Name                                            Address  \
# 0         David Smith                   PSC 4943, Box 1244\nAPO AA 95723
# 1         Casey Allen  21393 Patricia Point Suite 062\nGarciaville, L...
# 2                Umar                                          New Delhi
# 3       Thomas Nguyen  186 Hernandez Roads Apt. 015\nSabrinaside, LA ...
# 4  Heather Williamson  89142 Travis Harbors Apt. 624\nLake Richard, M...
# 5     Michael Kaufman  23964 Veronica Villages Apt. 964\nLarryburgh, ...
# 6         Brian Rivas    64576 Paul Points Apt. 172\nLake Lisa, DE 61303
# 7     Thomas Robinson       69102 Christine Corners\nLindatown, WA 35074
# 8        Vanessa Yang       86294 Alyssa Lights\nMadelinehaven, WY 47732
# 9     Stephen Simmons             2054 Jason Club\nSampsonland, SC 05019
#
#                   Email Address Date of Birth         Contact Number  \
# 0       stephanie11@example.com    1928-12-09          (479)658-9478
# ...

# %%
ds['Company'].apply(len)
# Out:
# 0    28
# 1    12
# 2     3
# 3    22
# 4    25
# 5    14
# 6    13
# 7    21
# 8    28
# 9    11
# Name: Company, dtype: int64

# %%
ds.apply(len)
# Out:
# Full Name         10
# Address           10
# Email Address     10
# Date of Birth     10
# Contact Number    10
# Company           10
# dtype: int64

# %%
len(ds['Full Name']) #return len value per column
# Out:
# 10

# %%
ds.apply(len,axis='columns')
# Out:
# 0    6
# 1    6
# 2    6
# 3    6
# 4    6
# 5    6
# 6    6
# 7    6
# 8    6
# 9    6
# dtype: int64

# %%
def update_email(Email):
    return Email.upper()

# %%
ds['Email Address'].apply(update_email)
# Out:
# 0         STEPHANIE11@EXAMPLE.COM
# 1      FISHERMICHELLE@EXAMPLE.NET
# 2                  UMAR@GMAIL.COM
# 3            NBRIDGES@EXAMPLE.NET
# 4    WILLIAMSNICHOLAS@EXAMPLE.COM
# 5         BRANDIMILLS@EXAMPLE.COM
# 6         YOUNGANDREW@EXAMPLE.NET
# 7        JOSEPHBARNES@EXAMPLE.NET
# 8         ELIZABETH81@EXAMPLE.ORG
# 9         ORTIZDENNIS@EXAMPLE.NET
# Name: Email Address, dtype: object

# %%
ds['Email Address']=ds['Email Address'].str.upper()

# %%
ds
# Out:
#             Full Name                                            Address  \
# 0         David Smith                   PSC 4943, Box 1244\nAPO AA 95723
# 1         Casey Allen  21393 Patricia Point Suite 062\nGarciaville, L...
# 2                Umar                                          New Delhi
# 3       Thomas Nguyen  186 Hernandez Roads Apt. 015\nSabrinaside, LA ...
# 4  Heather Williamson  89142 Travis Harbors Apt. 624\nLake Richard, M...
# 5     Michael Kaufman  23964 Veronica Villages Apt. 964\nLarryburgh, ...
# 6         Brian Rivas    64576 Paul Points Apt. 172\nLake Lisa, DE 61303
# 7     Thomas Robinson       69102 Christine Corners\nLindatown, WA 35074
# 8        Vanessa Yang       86294 Alyssa Lights\nMadelinehaven, WY 47732
# 9     Stephen Simmons             2054 Jason Club\nSampsonland, SC 05019
#
#                   Email Address Date of Birth         Contact Number  \
# 0       STEPHANIE11@EXAMPLE.COM    1928-12-09          (479)658-9478
# ...

# %%
ds['Email Address']=ds['Email Address'].apply(lambda x: x.lower())

# %%
ds
# Out:
#             Full Name                                            Address  \
# 0         David Smith                   PSC 4943, Box 1244\nAPO AA 95723
# 1         Casey Allen  21393 Patricia Point Suite 062\nGarciaville, L...
# 2                Umar                                          New Delhi
# 3       Thomas Nguyen  186 Hernandez Roads Apt. 015\nSabrinaside, LA ...
# 4  Heather Williamson  89142 Travis Harbors Apt. 624\nLake Richard, M...
# 5     Michael Kaufman  23964 Veronica Villages Apt. 964\nLarryburgh, ...
# 6         Brian Rivas    64576 Paul Points Apt. 172\nLake Lisa, DE 61303
# 7     Thomas Robinson       69102 Christine Corners\nLindatown, WA 35074
# 8        Vanessa Yang       86294 Alyssa Lights\nMadelinehaven, WY 47732
# 9     Stephen Simmons             2054 Jason Club\nSampsonland, SC 05019
#
#                   Email Address Date of Birth         Contact Number  \
# 0       stephanie11@example.com    1928-12-09          (479)658-9478
# ...

# %%
ds[['Full Name' , 'Company']].applymap(len)
# Out:
# C:\Users\Dell 4\AppData\Local\Temp\ipykernel_2032\395221071.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   ds[['Full Name' , 'Company']].applymap(len)
#    Full Name  Company
# 0         11       28
# 1         11       12
# 2          4        3
# 3         13       22
# 4         18       25
# 5         15       14
# 6         11       13
# 7         15       21
# 8         12       28
# 9         15       11

# %%
ds['Full Name']+''+ds['Email Address']
# Out:
# 0                David Smithstephanie11@example.com
# 1             Casey Allenfishermichelle@example.net
# 2                                Umarumar@gmail.com
# 3                 Thomas Nguyennbridges@example.net
# 4    Heather Williamsonwilliamsnicholas@example.com
# 5            Michael Kaufmanbrandimills@example.com
# 6                Brian Rivasyoungandrew@example.net
# 7           Thomas Robinsonjosephbarnes@example.net
# 8               Vanessa Yangelizabeth81@example.org
# 9            Stephen Simmonsortizdennis@example.net
# dtype: object

# %%
ds['Details']=ds ['Full Name'] +''+ds['Email Address']

# %%
ds
# Out:
#             Full Name                                            Address  \
# 0         David Smith                   PSC 4943, Box 1244\nAPO AA 95723
# 1         Casey Allen  21393 Patricia Point Suite 062\nGarciaville, L...
# 2                Umar                                          New Delhi
# 3       Thomas Nguyen  186 Hernandez Roads Apt. 015\nSabrinaside, LA ...
# 4  Heather Williamson  89142 Travis Harbors Apt. 624\nLake Richard, M...
# 5     Michael Kaufman  23964 Veronica Villages Apt. 964\nLarryburgh, ...
# 6         Brian Rivas    64576 Paul Points Apt. 172\nLake Lisa, DE 61303
# 7     Thomas Robinson       69102 Christine Corners\nLindatown, WA 35074
# 8        Vanessa Yang       86294 Alyssa Lights\nMadelinehaven, WY 47732
# 9     Stephen Simmons             2054 Jason Club\nSampsonland, SC 05019
#
#                   Email Address Date of Birth         Contact Number  \
# 0       stephanie11@example.com    1928-12-09          (479)658-9478
# ...

# %%
ds.drop(columns='Details')
# Out:
#             Full Name                                            Address  \
# 0         David Smith                   PSC 4943, Box 1244\nAPO AA 95723
# 1         Casey Allen  21393 Patricia Point Suite 062\nGarciaville, L...
# 2                Umar                                          New Delhi
# 3       Thomas Nguyen  186 Hernandez Roads Apt. 015\nSabrinaside, LA ...
# 4  Heather Williamson  89142 Travis Harbors Apt. 624\nLake Richard, M...
# 5     Michael Kaufman  23964 Veronica Villages Apt. 964\nLarryburgh, ...
# 6         Brian Rivas    64576 Paul Points Apt. 172\nLake Lisa, DE 61303
# 7     Thomas Robinson       69102 Christine Corners\nLindatown, WA 35074
# 8        Vanessa Yang       86294 Alyssa Lights\nMadelinehaven, WY 47732
# 9     Stephen Simmons             2054 Jason Club\nSampsonland, SC 05019
#
#                   Email Address Date of Birth         Contact Number  \
# 0       stephanie11@example.com    1928-12-09          (479)658-9478
# ...

# %%
ds['info']=ds ['Full Name'] +''+ds['Email Address']

# %%
ds['info'].str.split(' ',expand= True)
# Out:
#                     0                                       1
# 0               David            Smithstephanie11@example.com
# 1               Casey         Allenfishermichelle@example.net
# 2  Umarumar@gmail.com                                    None
# 3              Thomas              Nguyennbridges@example.net
# 4             Heather  Williamsonwilliamsnicholas@example.com
# 5             Michael          Kaufmanbrandimills@example.com
# 6               Brian            Rivasyoungandrew@example.net
# 7              Thomas        Robinsonjosephbarnes@example.net
# 8             Vanessa             Yangelizabeth81@example.org
# 9             Stephen          Simmonsortizdennis@example.net
