# %%
import pandas as pd

# %%
df=pd.read_csv("Student Depression Dataset.csv")

# %%
print(df)
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
# display the first  5 rows of dataset

# %%
df.head()
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
# display last 5 rows of dataset

# %%
df.tail()
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 27896  140685  Female  27.0      Surat    Student                5.0
# 27897  140686    Male  27.0   Ludhiana    Student                2.0
# 27898  140689    Male  31.0  Faridabad    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
# 27900  140699    Male  27.0      Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 27896            0.0  5.75                 5.0               0.0
# 27897            0.0  9.40                 3.0               0.0
# 27898            0.0  6.61                 4.0               0.0
# 27899            0.0  6.88                 2.0               0.0
# 27900            0.0  9.24                 1.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 27896          5-6 hours      Unhealthy  Class 12
# 27897  Less than 5 hours        Healthy       MSc
# ...

# %%
# display number of count of rows and columns

# %%
df.shape
# Out:
# (27901, 18)

# %%
# display summery and information about dataset including data types and non-null counts

# %%
df.info
# Out:
# <bound method DataFrame.info of            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
# ...

# %%
# Get descreptive statistics for numiracal column from dataset.

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
# select the age column from dataset.

# %%
df[['Age','CGPA']]
# Out:
#         Age  CGPA
# 0      33.0  8.97
# 1      24.0  5.90
# 2      31.0  7.03
# 3      28.0  5.59
# 4      25.0  8.13
# ...     ...   ...
# 27896  27.0  5.75
# 27897  27.0  9.40
# 27898  31.0  6.61
# 27899  18.0  6.88
# 27900  27.0  9.24
#
# [27901 rows x 2 columns]

# %%
# select 1st row by the index

# %%
df.iloc[0]
# Out:
# id                                                   2
# Gender                                            Male
# Age                                               33.0
# City                                     Visakhapatnam
# Profession                                     Student
# Academic Pressure                                  5.0
# Work Pressure                                      0.0
# CGPA                                              8.97
# Study Satisfaction                                 2.0
# Job Satisfaction                                   0.0
# Sleep Duration                               5-6 hours
# Dietary Habits                                 Healthy
# Degree                                         B.Pharm
# Have you ever had suicidal thoughts ?              Yes
# Work/Study Hours                                   3.0
# Financial Stress                                   1.0
# Family History of Mental Illness                    No
# ...

# %%
# select the row with lebal index 0 from dataset.

# %%
df.loc[0]
# Out:
# id                                                   2
# Gender                                            Male
# Age                                               33.0
# City                                     Visakhapatnam
# Profession                                     Student
# Academic Pressure                                  5.0
# Work Pressure                                      0.0
# CGPA                                              8.97
# Study Satisfaction                                 2.0
# Job Satisfaction                                   0.0
# Sleep Duration                               5-6 hours
# Dietary Habits                                 Healthy
# Degree                                         B.Pharm
# Have you ever had suicidal thoughts ?              Yes
# Work/Study Hours                                   3.0
# Financial Stress                                   1.0
# Family History of Mental Illness                    No
# ...

# %%
#  select row from 1 to 5 and column from 2 to 5.

# %%
df.iloc[1:5,2:5]
# Out:
#     Age       City Profession
# 1  24.0  Bangalore    Student
# 2  31.0   Srinagar    Student
# 3  28.0   Varanasi    Student
# 4  25.0     Jaipur    Student

# %%
# filter the dataset for the rows where age is greather then  30.

# %%
df[df['Age']>30]
# Out:
#            id Gender   Age           City Profession  Academic Pressure  \
# 0           2   Male  33.0  Visakhapatnam    Student                5.0
# 2          26   Male  31.0       Srinagar    Student                3.0
# 9          62   Male  31.0         Nashik    Student                2.0
# 11         91   Male  33.0       Vadodara    Student                3.0
# 26        186   Male  31.0      Ahmedabad    Student                2.0
# ...       ...    ...   ...            ...        ...                ...
# 27876  140536   Male  33.0         Nagpur    Student                1.0
# 27887  140624   Male  32.0         Rajkot    Student                4.0
# 27889  140631   Male  33.0      Ahmedabad    Student                1.0
# 27895  140684   Male  31.0        Lucknow    Student                2.0
# 27898  140689   Male  31.0      Faridabad    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
# use the query to filter the dataset for the rows where age is greather then  30.

# %%
df.query("Age > 30")
# Out:
#            id Gender   Age           City Profession  Academic Pressure  \
# 0           2   Male  33.0  Visakhapatnam    Student                5.0
# 2          26   Male  31.0       Srinagar    Student                3.0
# 9          62   Male  31.0         Nashik    Student                2.0
# 11         91   Male  33.0       Vadodara    Student                3.0
# 26        186   Male  31.0      Ahmedabad    Student                2.0
# ...       ...    ...   ...            ...        ...                ...
# 27876  140536   Male  33.0         Nagpur    Student                1.0
# 27887  140624   Male  32.0         Rajkot    Student                4.0
# 27889  140631   Male  33.0      Ahmedabad    Student                1.0
# 27895  140684   Male  31.0        Lucknow    Student                2.0
# 27898  140689   Male  31.0      Faridabad    Student                3.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
# check if there is any missing values in database

# %%
df.isnull()
# Out:
#           id  Gender    Age   City  Profession  Academic Pressure  \
# 0      False   False  False  False       False              False
# 1      False   False  False  False       False              False
# 2      False   False  False  False       False              False
# 3      False   False  False  False       False              False
# 4      False   False  False  False       False              False
# ...      ...     ...    ...    ...         ...                ...
# 27896  False   False  False  False       False              False
# 27897  False   False  False  False       False              False
# 27898  False   False  False  False       False              False
# 27899  False   False  False  False       False              False
# 27900  False   False  False  False       False              False
#
#        Work Pressure   CGPA  Study Satisfaction  Job Satisfaction  \
# 0              False  False               False             False
# ...

# %%
# count a number of missing value in the dataset.

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
# fill missing values with zero(0).

# %%
df.fillna(0)
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.dtypes
# Out:
# id                                         int64
# Gender                                    object
# Age                                      float64
# City                                      object
# Profession                                object
# Academic Pressure                        float64
# Work Pressure                            float64
# CGPA                                     float64
# Study Satisfaction                       float64
# Job Satisfaction                         float64
# Sleep Duration                            object
# Dietary Habits                            object
# Degree                                    object
# Have you ever had suicidal thoughts ?     object
# Work/Study Hours                         float64
# Financial Stress                         float64
# Family History of Mental Illness          object
# Depression                                 int64
# dtype: object

# %%
df.sort_values(by='Age',ascending=False).head()
# Out:
#           id  Gender   Age      City Profession  Academic Pressure  \
# 9238   46602    Male  59.0    Nashik    Student                1.0
# 2909   14768  Female  58.0   Chennai    Student                4.0
# 14819  74887  Female  56.0  Ludhiana    Student                3.0
# 13499  68441    Male  54.0      Agra    Student                5.0
# 4386   22004  Female  51.0    Bhopal    Student                2.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 9238             0.0  8.14                 1.0               0.0
# 2909             0.0  8.58                 1.0               0.0
# 14819            0.0  7.94                 5.0               0.0
# 13499            0.0  9.60                 2.0               0.0
# 4386             0.0  8.26                 3.0               0.0
#
#           Sleep Duration Dietary Habits    Degree  \
# 9238           5-6 hours      Unhealthy       PhD
# 2909           7-8 hours        Healthy  Class 12
# ...

# %%
df['CGPA'].min()
# Out:
# 0.0

# %%
df['CGPA'].max()
# Out:
# 10.0

# %%
# filter for high financial stress

# %%
df[df['Have you ever had suicidal thoughts ?']=='Yes']
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# 8          59    Male  28.0         Nagpur    Student                3.0
# 9          62    Male  31.0         Nashik    Student                2.0
# ...       ...     ...   ...            ...        ...                ...
# 27894  140681    Male  23.0       Srinagar    Student                3.0
# 27895  140684    Male  31.0        Lucknow    Student                2.0
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df[df['Financial Stress']>3]
# Out:
#            id  Gender   Age       City Profession  Academic Pressure  \
# 3          30  Female  28.0   Varanasi    Student                3.0
# 9          62    Male  31.0     Nashik    Student                2.0
# 14        103  Female  19.0     Kalyan    Student                5.0
# 16        120    Male  25.0     Nashik    Student                5.0
# 22        166  Female  25.0  Ahmedabad    Student                3.0
# ...       ...     ...   ...        ...        ...                ...
# 27883  140584  Female  22.0     Kanpur    Student                4.0
# 27887  140624    Male  32.0     Rajkot    Student                4.0
# 27891  140645  Female  28.0      Thane    Student                4.0
# 27894  140681    Male  23.0   Srinagar    Student                3.0
# 27899  140690  Female  18.0   Ludhiana    Student                5.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 3                0.0  5.59                 2.0               0.0
# ...

# %%
df['Have you ever had suicidal thoughts ?'].map({"Yes":1,"No":0})
# Out:
# 0        1
# 1        0
# 2        0
# 3        1
# 4        1
#         ..
# 27896    1
# 27897    0
# 27898    0
# 27899    1
# 27900    1
# Name: Have you ever had suicidal thoughts ?, Length: 27901, dtype: int64

# %%
# select the element in the first row and first column.
df.iloc[0,0]
# Out:
# 2

# %%
# Find all row ehere gender is male and depression is 1.
df[(df['Gender']=='Male')&(df['Depression']==1)]
# Out:
#            id Gender   Age           City Profession  Academic Pressure  \
# 0           2   Male  33.0  Visakhapatnam    Student                5.0
# 8          59   Male  28.0         Nagpur    Student                3.0
# 9          62   Male  31.0         Nashik    Student                2.0
# 10         83   Male  24.0         Nagpur    Student                3.0
# 12         94   Male  27.0         Kalyan    Student                5.0
# ...       ...    ...   ...            ...        ...                ...
# 27881  140564   Male  27.0          Surat    Student                4.0
# 27884  140594   Male  18.0         Meerut    Student                5.0
# 27887  140624   Male  32.0         Rajkot    Student                4.0
# 27888  140630   Male  19.0        Kolkata    Student                4.0
# 27900  140699   Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
#select the first three row of age and CGPA column.
df.loc[0:2,['Age','CGPA']]
# Out:
#     Age  CGPA
# 0  33.0  8.97
# 1  24.0  5.90
# 2  31.0  7.03

# %%
# Change the sleep duration fro the person with ID = 1 too ,8 to 9hrs.
if(df['id']==0).any():
    df.loc[df['id']==0,'Sleep Duration']='8-9 Hours' 
    print(df.loc[df['id']==0])
else:
      print("Not row with id==0 found.")
# Out:
# Not row with id==0 found.

# %%
# Print the 1st and 5th row along with second column.
df.iloc[[0,5],2]
# Out:
# 0    33.0
# 5    29.0
# Name: Age, dtype: float64

# %%
df.loc[[0,5],'City']
# Out:
# 0    Visakhapatnam
# 5             Pune
# Name: City, dtype: object

# %%
df['City'].value_counts()
# Out:
# City
# Kalyan                1570
# Srinagar              1372
# Hyderabad             1340
# Vasai-Virar           1290
# Lucknow               1155
# Thane                 1139
# Ludhiana              1111
# Agra                  1094
# Surat                 1078
# Kolkata               1066
# Jaipur                1036
# Patna                 1007
# Visakhapatnam          969
# Pune                   968
# Ahmedabad              951
# Bhopal                 934
# Chennai                885
# Meerut                 825
# Rajkot                 816
# Delhi                  768
# Bangalore              767
# Ghaziabad              745
# Mumbai                 699
# Vadodara               694
# Varanasi               685
# Nagpur                 651
# Indore                 643
# Kanpur                 609
# Nashik                 547
# Faridabad              461
# Saanvi                   2
# Bhavna                   2
# City                     2
# Harsha                   2
# ...

# %%
# Degree and sleep durtion start from index 1 to index 18 skip value 2.
df.loc[1:18:2,['Degree','Sleep Duration']]
# Out:
#       Degree     Sleep Duration
# 1        BSc          5-6 hours
# 3        BCA          7-8 hours
# 5        PhD  Less than 5 hours
# 7   Class 12  Less than 5 hours
# 9        LLB  Less than 5 hours
# 11        BE  Less than 5 hours
# 13  Class 12  Less than 5 hours
# 15    M.Tech  More than 8 hours
# 17  Class 12          5-6 hours

# %%
#
df.loc[1:18:2,'City':'CGPA']
# Out:
#          City Profession  Academic Pressure  Work Pressure  CGPA
# 1   Bangalore    Student                2.0            0.0  5.90
# 3    Varanasi    Student                3.0            0.0  5.59
# 5        Pune    Student                2.0            0.0  5.70
# 7     Chennai    Student                2.0            0.0  8.04
# 9      Nashik    Student                2.0            0.0  8.38
# 11   Vadodara    Student                3.0            0.0  7.03
# 13     Rajkot    Student                2.0            0.0  8.52
# 15   Srinagar    Student                3.0            0.0  8.58
# 17  Ahmedabad    Student                5.0            0.0  7.25

# %%
#Write a code to filter a dataset and select row where the city column is Kalyan , jaipur or Delhi and then select only Financial stress column from the filtered rows.
